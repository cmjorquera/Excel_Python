# %%
import pandas as pd
path_file = "Base_datos.xlsx"
col_types = {"isbn":str,"isbn13":str}
hoja = "data"
df = pd.read_excel(path_file,sheet_name=hoja,dtype=col_types)

# %%
df.columns.values
# Out:
# array(['ID ', 'Nombre', 'Apellido_Mater', 'Apellido_pater', 'Edad',
#        'Nacionalidad', 'Telefono ', 'Genero ', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype=object)

# %%
df
# Out:
#      ID       Nombre Apellido_Mater Apellido_pater  Edad Nacionalidad  \
# 0    NaN         NaN            NaN            NaN   NaN          NaN
# 1    1.0   Cristian        Jorquera       Gonzalez  35.0      Chilena
# 2    2.0   Guadalupe       Jorquera        Caicedo   1.0      Chilena
# 3    3.0       Laura        Caicedo        Bonilla  32.0   Colombiana
# 4    4.0      Jesus         Alvarez       Gonzalez  24.0   Venezolana
# 5    5.0     Tamara           Villa       Gonzalez  25.0      Chilena
# 6    6.0    Cristina       Gonzalez        Cornejo  55.0      Chilena
# 7    7.0   Jonathan         Vergara       Cariqueo  34.0      Chilena
# 8    8.0     Anibal        Carvajal        Salazar  34.0      Chilena
# 9    9.0   Mauricio         Canales        Canales  36.0      Chilena
# 10  10.0        Ana        Mendoza         Mendoca  34.0    Brasileña
# 11  11.0      Jenny           Cofre           Lara  21.0   Venezolana
# 12  12.0      Harlys     Contreras           Parra  26.0   Venezolana
# 13  13.0       Rosa        Gonzalez       Cornejos  55.0      Chilena
# 14  14.0     Daniel        Jorquera           Diaz   5.0      Chileno
# 15  15.0  Sebastian          Piñera      Echeñique  60.0      Chileno
#
#       Telefono      Genero   Unnamed: 8  Unnamed: 9
# 0           NaN         NaN         NaN         NaN
# 1   988302735.0  Masculino          NaN         NaN
# 2   984579874.0    Femenina         NaN         NaN
# 3    98546321.0    Femenina         NaN         NaN
# 4    54879332.0  Masculino          NaN         NaN
# 5     4586321.0    Femenina         NaN         NaN
# 6    42566681.0    Femenina         NaN         NaN
# 7     1234587.0  Masculino          NaN         NaN
# 8    54896412.0  Masculino          NaN         NaN
# 9    12365789.0  Masculino          NaN         NaN
# 10    2369656.0    Femenina         NaN         NaN
# 11   12548799.0    Femenina         NaN         NaN
# 12    4589799.0    Femenina         NaN         NaN
# 13   12032178.0    Femenina         NaN         NaN
# 14  120336987.0  Masculino          NaN         NaN
# 15    7845955.0  Masculino          NaN         NaN

# %%
outfile = "descarga.xlsx"
writer = df.ExcelWriter()
writer.save()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-42620c39b651> in <module>
#       1 outfile = "descarga.xlsx"
# ----> 2 writer = df.ExcelWriter()
#       3 writer.save()
#
# c:\users\cmjor\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ExcelWriter'

# %%
df.shape
# Out:
# (16, 10)
